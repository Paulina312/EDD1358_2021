# %% [markdown]
# <a href="https://colab.research.google.com/github/Paulina312/EDD1358_2021/blob/master/Tarea_30_de_octubre_1358.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
archivo = open('junio.dat', "rt", errors='ignore')
data = archivo.readlines()
emp = []
for linea in data:
  emp.append(linea.strip())
emp_final = []
for elem in emp:
  emp_final.append(elem.split(','))
archivo.close()

class Empleado:
  def __init__( self, num, nom, pat, mat, he, sb, anio):
    self.__num_trabajador = num
    self.__nombres = nom
    self.__paterno = pat
    self.__materno = mat
    self.__horas_extra = he
    self.__sueldo_base = sb
    self.__anio_de_ingreso = anio

  def get_datos(self):
    return (self.__num_trabajador, self.__nombres, self.__paterno, self.__materno, self.__horas_extra, self.__sueldo_base, self.__anio_de_ingreso)

  def set_num_trabajador(self, dato):
    self.__num_trabajador = dato

  def set_nombres(self, dato):
    self.__nombres = dato

  def set_paterno(self, dato):
    self.__paterno = dato

  def set_materno(self, dato):
    self.__materno = dato

  def set_horas_extra(self, dato):
    self.__horas_extra = dato

  def set_sueldo_base(self, dato):
    self.__sueldo_base = dato

  def set_anio_de_ingreso(self, dato):
    self.__anio_de_ingreso = dato

  def cargar_datos(self, ruta_archivo):
    archivo = open(ruta_archivo, "rt", errors='ignore')
    data = archivo.readlines()
    emp = []
    for linea in data:
      emp.append(linea.strip())
    emp_final = []
    for elem in emp:
      emp_final.append(elem.split(','))
    archivo.close()
      
  def calcular_sueldo(self):
    hrs_extra = 276.5 * float(self.__horas_extra)
    ant = 2020 - float(self.__anio_de_ingreso)
    ant2 = ant * 0.03
    ant3 = ant2 * float(self.__sueldo_base)
    sueldo = hrs_extra + float(self.__sueldo_base) + ant3
    print(sueldo)
  
  def mayor_ant(self):
    self.cargar_datos('junio.dat')
    emp_final.pop(0)
    antiguedad = []
    for lista in emp_final:
      antiguedad.append(int(lista[6]))
    may_ant = min(antiguedad)
    print("Empleados con mayor antigüedad:")
    for lista in emp_final:
      if int(lista[-1]) == may_ant:
        print(lista[1] +' '+ lista[2])

  def menor_ant(self):
    self.cargar_datos('junio.dat')
    antiguedad = []
    for lista in emp_final:
      antiguedad.append(int(lista[6]))
    men_ant = max(antiguedad)
    print("Empleados con menor antigüedad:")
    for lista in emp_final:
      if int(lista[-1]) == men_ant:
        print(lista[1] +' '+ lista[2])
    
class Sueldos:
  def __init(self):
    self.__data = None

  def cargar_datos(self, ruta_archivo):
    archivo = open(ruta_archivo, "rt", errors='ignore')
    data = archivo.readlines()
    emp = []
    for linea in data:
      emp.append(linea.strip())
    emp_final = []
    for elem in emp:
      emp_final.append(elem.split(','))
    archivo.close()
    self.__data = Array(len(emp_final)-1)
  
index = 1
empleado_1 = Empleado(emp_final[index][0], emp_final[index][1], emp_final[index][2], emp_final[index][3], emp_final[index][4], emp_final[index][5], emp_final[index][6])
index = 2
empleado_2 = Empleado(emp_final[index][0], emp_final[index][1], emp_final[index][2], emp_final[index][3], emp_final[index][4], emp_final[index][5], emp_final[index][6])
index = 3
empleado_3 = Empleado(emp_final[index][0], emp_final[index][1], emp_final[index][2], emp_final[index][3], emp_final[index][4], emp_final[index][5], emp_final[index][6])
index = 4
empleado_4 = Empleado(emp_final[index][0], emp_final[index][1], emp_final[index][2], emp_final[index][3], emp_final[index][4], emp_final[index][5], emp_final[index][6])
index = 5
empleado_5 = Empleado(emp_final[index][0], emp_final[index][1], emp_final[index][2], emp_final[index][3], emp_final[index][4], emp_final[index][5], emp_final[index][6])
index = 6
empleado_6 = Empleado(emp_final[index][0], emp_final[index][1], emp_final[index][2], emp_final[index][3], emp_final[index][4], emp_final[index][5], emp_final[index][6])
index = 7
empleado_7 = Empleado(emp_final[index][0], emp_final[index][1], emp_final[index][2], emp_final[index][3], emp_final[index][4], emp_final[index][5], emp_final[index][6])
index = 8
empleado_8 = Empleado(emp_final[index][0], emp_final[index][1], emp_final[index][2], emp_final[index][3], emp_final[index][4], emp_final[index][5], emp_final[index][6])
index = 9
empleado_9 = Empleado(emp_final[index][0], emp_final[index][1], emp_final[index][2], emp_final[index][3], emp_final[index][4], emp_final[index][5], emp_final[index][6])
index = 10
empleado_10 = Empleado(emp_final[index][0], emp_final[index][1], emp_final[index][2], emp_final[index][3], emp_final[index][4], emp_final[index][5], emp_final[index][6])
index = 11
empleado_11 = Empleado(emp_final[index][0], emp_final[index][1], emp_final[index][2], emp_final[index][3], emp_final[index][4], emp_final[index][5], emp_final[index][6])
index = 12
empleado_12 = Empleado(emp_final[index][0], emp_final[index][1], emp_final[index][2], emp_final[index][3], emp_final[index][4], emp_final[index][5], emp_final[index][6])
index = 13
empleado_13 = Empleado(emp_final[index][0], emp_final[index][1], emp_final[index][2], emp_final[index][3], emp_final[index][4], emp_final[index][5], emp_final[index][6])
index = 14
empleado_14 = Empleado(emp_final[index][0], emp_final[index][1], emp_final[index][2], emp_final[index][3], emp_final[index][4], emp_final[index][5], emp_final[index][6])

print(empleado_1.get_datos())
empleado_1.calcular_sueldo()
empleado_2.calcular_sueldo()
empleado_3.calcular_sueldo()
empleado_4.calcular_sueldo()
empleado_5.calcular_sueldo()
empleado_6.calcular_sueldo()
empleado_7.calcular_sueldo()
empleado_8.calcular_sueldo()
empleado_9.calcular_sueldo()
empleado_10.calcular_sueldo()
empleado_11.calcular_sueldo()
empleado_12.calcular_sueldo()
empleado_13.calcular_sueldo()
empleado_14.calcular_sueldo()

empleado_1.mayor_ant()
empleado_1.menor_ant()
# Out:
# ('2345', 'CARLOS', 'PEREZ', 'CASTILLO', '0', '9850', '2017')
# 10736.5
# 10126.5
# 11585.0
# 11289.5
# 11289.5
# 11270.5
# 10994.0
# 10717.5
# 11013.0
# 11289.5
# 11251.5
# 10422.0
# 10403.0
# 11308.5
# Empleados con mayor antigüedad:
# JESUS MARTIN
# RAMON NAVARRO
# Empleados con menor antigüedad:
# ANGEL GOMEZ
# JORGE GUTIERREZ
